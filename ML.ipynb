# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("C://Users//kamal//Desktop//Pro/Pro Delhi.xlsx")

# %%
df
# Out:
#        City       Date   PM2.5    PM10     NO    NO2     NOx     NH3     CO  \
# 0     Delhi 2015-01-01  313.22  607.98  69.16  36.39  110.59   33.85  15.20
# 1     Delhi 2015-01-02  186.18  269.55  62.09  32.87   88.14   31.83   9.54
# 2     Delhi 2015-01-03   87.18  131.90  25.73  30.31   47.95   69.55  10.61
# 3     Delhi 2015-01-04  151.84  241.84  25.01  36.91   48.62  130.36  11.54
# 4     Delhi 2015-01-05  146.60  219.13  14.01  34.92   38.25  122.88   9.20
# ...     ...        ...     ...     ...    ...    ...     ...     ...    ...
# 2004  Delhi 2020-06-27   39.80  155.94  10.88  21.46   22.47   31.43   0.87
# 2005  Delhi 2020-06-28   59.52  308.65  12.67  21.60   23.86   29.27   0.94
# 2006  Delhi 2020-06-29   44.86  184.12  10.50  21.57   21.94   27.97   0.88
# 2007  Delhi 2020-06-30   39.80   91.98   5.99  17.96   15.44   28.48   0.84
# 2008  Delhi 2020-07-01   54.01  128.66   6.33  21.05   16.81   29.06   0.97
#
# ...

# %%
df=df.drop(["City","PM2.5","PM10","NO","NO2","NOx","NH3","CO","SO2","O3","Benzene","Toluene","Xylene"],axis=1)

# %%
df=df.drop("AQI_Bucket",axis=1)

# %%
df
# Out:
#            Date    AQI
# 0    2015-01-01  472.0
# 1    2015-01-02  454.0
# 2    2015-01-03  143.0
# 3    2015-01-04  319.0
# 4    2015-01-05  325.0
# ...         ...    ...
# 2004 2020-06-27  112.0
# 2005 2020-06-28  196.0
# 2006 2020-06-29  233.0
# 2007 2020-06-30  114.0
# 2008 2020-07-01  101.0
#
# [2009 rows x 2 columns]

# %%
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["Date"]=df["Date"].astype(str)

# %%
df["Date"].dtype
# Out:
# dtype('O')

# %%
df["DateTime"]=df["Date"].str[5:]

# %%
df
# Out:
#             Date    AQI DateTime
# 0     2015-01-01  472.0    01-01
# 1     2015-01-02  454.0    01-02
# 2     2015-01-03  143.0    01-03
# 3     2015-01-04  319.0    01-04
# 4     2015-01-05  325.0    01-05
# ...          ...    ...      ...
# 2004  2020-06-27  112.0    06-27
# 2005  2020-06-28  196.0    06-28
# 2006  2020-06-29  233.0    06-29
# 2007  2020-06-30  114.0    06-30
# 2008  2020-07-01  101.0    07-01
#
# [2009 rows x 3 columns]

# %%
df["Date"]=df["Date"].str[5:]

# %%
df
# Out:
#        Date    AQI DateTime
# 0     01-01  472.0    01-01
# 1     01-02  454.0    01-02
# 2     01-03  143.0    01-03
# 3     01-04  319.0    01-04
# 4     01-05  325.0    01-05
# ...     ...    ...      ...
# 2004  06-27  112.0    06-27
# 2005  06-28  196.0    06-28
# 2006  06-29  233.0    06-29
# 2007  06-30  114.0    06-30
# 2008  07-01  101.0    07-01
#
# [2009 rows x 3 columns]

# %%
df=df.drop("DateTime",axis=1)

# %%
df
# Out:
#        Date    AQI
# 0     01-01  472.0
# 1     01-02  454.0
# 2     01-03  143.0
# 3     01-04  319.0
# 4     01-05  325.0
# ...     ...    ...
# 2004  06-27  112.0
# 2005  06-28  196.0
# 2006  06-29  233.0
# 2007  06-30  114.0
# 2008  07-01  101.0
#
# [2009 rows x 2 columns]

# %%
df["Date"]=df["Date"].str.replace('[-]','')

# %%
df
# Out:
#       Date    AQI
# 0     0101  472.0
# 1     0102  454.0
# 2     0103  143.0
# 3     0104  319.0
# 4     0105  325.0
# ...    ...    ...
# 2004  0627  112.0
# 2005  0628  196.0
# 2006  0629  233.0
# 2007  0630  114.0
# 2008  0701  101.0
#
# [2009 rows x 2 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df)
# Out:
#       Date    AQI
# 0     0101  472.0
# 1     0102  454.0
# 2     0103  143.0
# 3     0104  319.0
# 4     0105  325.0
# 5     0106  318.0
# 6     0107  353.0
# 7     0108  383.0
# 8     0109  375.0
# 9     0110  376.0
# 10    0111  379.0
# 11    0112  375.0
# 12    0113  366.0
# 13    0114  353.0
# 14    0115  340.0
# 15    0116  356.0
# 16    0117  360.0
# 17    0118  370.0
# 18    0119  362.0
# 19    0120  340.0
# 20    0121  338.0
# 21    0122  332.0
# 22    0123  254.0
# 23    0124  324.0
# 24    0125  333.0
# 25    0126  292.0
# 26    0127  318.0
# 27    0128  295.0
# 28    0129  327.0
# 29    0130  345.0
# 30    0131  334.0
# 31    0201  358.0
# 32    0202  349.0
# 33    0203  334.0
# 34    0204  313.0
# 35    0205  262.0
# 36    0206  303.0
# 37    0207  329.0
# 38    0208  323.0
# 39    0209  266.0
# 40    0210  319.0
# 41    0211  334.0
# 42    0212  342.0
# 43    0213  341.0
# 44    0214  377.0
# 45    0215  391.0
# 46    0216  358.0
# 47    0217  327.0
# 48    0218  365.0
# ...

# %%
df.isna().sum()
# Out:
# Date     0
# AQI     10
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df["Date"]=df["Date"].astype(int)

# %%
df["Date"].dtype
# Out:
# dtype('int32')

# %%
df["AQI"].dtype
# Out:
# dtype('float64')

# %%
np.random.seed(7)
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
df
# Out:
#       Date    AQI
# 0      101  472.0
# 1      102  454.0
# 2      103  143.0
# 3      104  319.0
# 4      105  325.0
# ...    ...    ...
# 2004   627  112.0
# 2005   628  196.0
# 2006   629  233.0
# 2007   630  114.0
# 2008   701  101.0
#
# [1999 rows x 2 columns]

# %%
X=df.drop("AQI",axis=1)

# %%
y=df["AQI"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
model=RandomForestRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(X_train,y_train)
# Out:
# 0.6285491828551453

# %%
model.score(X_test,y_test)
# Out:
# 0.39277664464405126

# %%
model.predict([[918]])
# Out:
# array([167.3376627])

# %%
#https://docs.google.com/spreadsheets/d/1-bJGRC_dkE4ft1SiTyPPHxQV1-PUeSajgZhf0ZMweU4/edit#gid=0

# %%
sheet_id="1-bJGRC_dkE4ft1SiTyPPHxQV1-PUeSajgZhf0ZMweU4"
xls=(f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=xlsx")
pf=pd.read_excel(xls,"Sheet1")

# %%
pf
# Out:
#      Date
# 0     918
# 1     919
# 2     920
# 3     921
# 4     922
# ..    ...
# 100  1227
# 101  1228
# 102  1229
# 103  1230
# 104  1231
#
# [105 rows x 1 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(pf)
# Out:
#      Date
# 0     918
# 1     919
# 2     920
# 3     921
# 4     922
# 5     923
# 6     924
# 7     925
# 8     926
# 9     927
# 10    928
# 11    929
# 12    930
# 13   1001
# 14   1002
# 15   1003
# 16   1004
# 17   1005
# 18   1006
# 19   1007
# 20   1008
# 21   1009
# 22   1010
# 23   1011
# 24   1012
# 25   1013
# 26   1014
# 27   1015
# 28   1016
# 29   1017
# 30   1018
# 31   1019
# 32   1020
# 33   1021
# 34   1022
# 35   1023
# 36   1024
# 37   1025
# 38   1026
# 39   1027
# 40   1028
# 41   1029
# 42   1030
# 43   1031
# 44   1101
# 45   1102
# 46   1103
# 47   1104
# 48   1105
# 49   1106
# 50   1107
# 51   1108
# 52   1109
# 53   1110
# 54   1111
# 55   1112
# 56   1113
# 57   1114
# 58   1115
# 59   1116
# 60   1117
# 61   1118
# 62   1119
# 63   1120
# 64   1121
# 65   1122
# 66   1123
# 67   1124
# 68   1125
# 69   1126
# 70   1127
# 71   1128
# 72   1129
# 73   1130
# 74   1201
# 75   1202
# 76   1203
# 77   1204
# 78   1205
# 79   1206
# 80   1207
# 81   1208
# ...

# %%
z=model.predict(pf)

# %%
bg=pd.DataFrame(z)

# %%
bg
# Out:
#               0
# 0    167.337663
# 1    135.263893
# 2    177.043001
# 3    175.399694
# 4    100.969405
# ..          ...
# 100  384.285881
# 101  420.318198
# 102  425.168690
# 103  431.624667
# 104  418.995234
#
# [105 rows x 1 columns]

# %%
print(bg.to_string(index=False))
# Out:
#           0
#  167.337663
#  135.263893
#  177.043001
#  175.399694
#  100.969405
#   96.521513
#  139.130968
#  143.127886
#  166.665414
#  180.306464
#  174.430571
#  199.006361
#  183.221524
#  155.932444
#  187.298033
#  178.142488
#  279.043540
#  224.869258
#  206.117877
#  266.900524
#  273.015587
#  315.979127
#  284.371323
#  270.137329
#  203.242111
#  281.965059
#  251.550333
#  316.816833
#  328.552190
#  379.058595
#  333.872249
#  327.694587
#  375.621036
#  377.491402
#  332.070587
#  344.938274
#  374.842132
#  363.990607
#  360.722377
#  365.843655
#  420.311548
#  349.410655
#  384.362857
#  418.910865
#  475.530282
#  432.799246
#  467.927944
#  404.281167
#  435.060698
#  345.688500
#  510.096131
#  498.467056
#  479.909913
#  463.226103
#  450.584172
#  483.459010
#  476.478699
#  440.972948
#  396.107571
#  401.503964
#  350.980066
#  344.766034
#  324.802218
#  379.066476
#  393.682353
#  405.508310
#  390.996960
#  365.513246
#  310.962607
#  347.951885
# ...

# %%
model.predict([[918]])
# Out:
# array([167.3376627])
